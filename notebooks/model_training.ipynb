# %%
import joblib
# Save trained model object named `model` to ../model/risk_model.pkl
joblib.dump(model, "../model/risk_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import joblib
#       2 # Save trained model object named `model` to ../model/risk_model.pkl
# ----> 3 joblib.dump(model, "../model/risk_model.pkl")
#
# NameError: name 'model' is not defined
